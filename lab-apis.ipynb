# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
from credentials import CLIENT_SECRET , CLIENT_ID

# %%
CLIENT_ID_x = "<introduce your client id>"
CLIENT_SECRET_x = "<introduce your client secret>"

#no es una buena práctica... estarán en un nuevo doc que vamos a importar

# %%
CLIENT_ID = CLIENT_ID
CLIENT_SECRET = CLIENT_SECRET

#no es una buena práctica... estarán en un nuevo doc que vamos a importar

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials; 
#Si fuera otra página, esta inicialización debería estar dentro de la documentación

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
# ...

# %%
results.keys() # We can see that we only have tracks

# %%
results["tracks"].keys() # Let's check the values

# %%
results["tracks"]["href"] # Query we have searched

# %%
results["tracks"]["items"] #items (actual tracks)

# %%
results["tracks"]["items"][0].keys()

# %%
len(results["tracks"]["items"])

# %%
results["tracks"]["items"][49]  #1st Jason

# %%
results["tracks"]["limit"] #Limit we have chosen

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)

# %%
results["tracks"]["offset"] # Actual offset (starting point)

# %%
results["tracks"]["previous"] #Previous search

# %%
type(results["tracks"]["previous"]) #Previous search

# %%
results["tracks"]["total"] # Number of matches

# %%
type(results["tracks"]["total"])

# %% [markdown]
# ## Exploring the tracks

# %%
results_V = sp.search(q='Deborah de Luca', limit=1)
results_V
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Deborah+de+Luca&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/144HzhpLjcR9k37w5Ico9B'},
#        'href': 'https://api.spotify.com/v1/artists/144HzhpLjcR9k37w5Ico9B',
#        'id': '144HzhpLjcR9k37w5Ico9B',
#        'name': 'Deborah de Luca',
#        'type': 'artist',
#        'uri': 'spotify:artist:144HzhpLjcR9k37w5Ico9B'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YVF0Ou5zIc4mpgtLIlGN0'},
#        'href': 'https://api.spotify.com/v1/artists/2YVF0Ou5zIc4mpgtLIlGN0',
#        'id': '2YVF0Ou5zIc4mpgtLIlGN0',
#        'name': 'Robert Miles',
#        'type': 'artist',
#        'uri': 'spotify:artist:2YVF0Ou5zIc4mpgtLIlGN0'}],
#      'available_markets': ['AR',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
# ...

# %%
results_V["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/144HzhpLjcR9k37w5Ico9B'},
#     'href': 'https://api.spotify.com/v1/artists/144HzhpLjcR9k37w5Ico9B',
#     'id': '144HzhpLjcR9k37w5Ico9B',
#     'name': 'Deborah de Luca',
#     'type': 'artist',
#     'uri': 'spotify:artist:144HzhpLjcR9k37w5Ico9B'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YVF0Ou5zIc4mpgtLIlGN0'},
#     'href': 'https://api.spotify.com/v1/artists/2YVF0Ou5zIc4mpgtLIlGN0',
#     'id': '2YVF0Ou5zIc4mpgtLIlGN0',
#     'name': 'Robert Miles',
#     'type': 'artist',
#     'uri': 'spotify:artist:2YVF0Ou5zIc4mpgtLIlGN0'}],
#   'available_markets': ['AR',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
# ...

# %%
results_V["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results_V["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/144HzhpLjcR9k37w5Ico9B'},
#   'href': 'https://api.spotify.com/v1/artists/144HzhpLjcR9k37w5Ico9B',
#   'id': '144HzhpLjcR9k37w5Ico9B',
#   'name': 'Deborah de Luca',
#   'type': 'artist',
#   'uri': 'spotify:artist:144HzhpLjcR9k37w5Ico9B'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YVF0Ou5zIc4mpgtLIlGN0'},
#   'href': 'https://api.spotify.com/v1/artists/2YVF0Ou5zIc4mpgtLIlGN0',
#   'id': '2YVF0Ou5zIc4mpgtLIlGN0',
#   'name': 'Robert Miles',
#   'type': 'artist',
#   'uri': 'spotify:artist:2YVF0Ou5zIc4mpgtLIlGN0'}]

# %%
# Track artists
results_V["tracks"]["items"][0]["artists"][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/144HzhpLjcR9k37w5Ico9B'},
#  'href': 'https://api.spotify.com/v1/artists/144HzhpLjcR9k37w5Ico9B',
#  'id': '144HzhpLjcR9k37w5Ico9B',
#  'name': 'Deborah de Luca',
#  'type': 'artist',
#  'uri': 'spotify:artist:144HzhpLjcR9k37w5Ico9B'}

# %%
# Track artists
results_V["tracks"]["items"][0]["artists"][0]["name"]
# Out:
# 'Deborah de Luca'

# %%
# Track artists names
for artist in results_V["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Deborah de Luca
# Robert Miles

# %%
# Track ID
results_V["tracks"]["items"][0]["id"]
# Out:
# '7Bg90Jhm3Dhtu7m2YCpo6C'

# %%
# Track name
results_V["tracks"]["items"][0]["name"]
# Out:
# 'Children - Radio Edit'

# %%
# Popularity index
results_V["tracks"]["items"][0]["popularity"]
# Out:
# 59

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
id_ = results_V["tracks"]["items"][0]["id"]
id_
# Out:
# '7Bg90Jhm3Dhtu7m2YCpo6C'

# %%
name = "Deborah de Luca"
name
# Out:
# 'Deborah de Luca'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials; 
#Si fuera otra página, esta inicialización debería estar dentro de la documentación


sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

import sys

# %%
artists = ["Deborah de Luca", "Willie Colón", "Yann Tiersen"]

# %%
top_tracks_list_test = []
for artist in artists:
    
    results_ = sp.search( q=artist , limit = 5)

    for i in range(5):
        song_name = results_["tracks"]["items"][i]["name"]
        top_tracks_list_test.append(song_name)

# %%
top_tracks_list_test
# Out:
# ['Children - Radio Edit',
#  'Croce',
#  'Devotion - Show Me Love 2023 Techno Mix - Radio Edit',
#  "You're Toxic",
#  'Gam Gam - 2023',
#  'Oh Qué Será?',
#  'Talento De Televisión',
#  'Idilio',
#  'El Día De Mi Suerte',
#  'Pedro Navaja',
#  "Comptine d'un autre été, l'après-midi",
#  "La Valse d'Amélie - Version piano",
#  'Le Matin',
#  "I've Never Been There",
#  "La valse d'Amélie"]

# %%
def get_top_tracks(name):
    
    top_tracks = []
    results_ = sp.search( q = name , limit = 5)

    for i in range(5):
        song_name = results_["tracks"]["items"][i]["name"]
        top_tracks.append(song_name)
        
    
    return (top_tracks)

# %%
get_top_tracks("Willie Colón")
# Out:
# ['Oh Qué Será?',
#  'Talento De Televisión',
#  'Idilio',
#  'El Día De Mi Suerte',
#  'Pedro Navaja']

# %%
top_tracks_list = list( map(get_top_tracks, artists) )

# %%
top_tracks_list
# Out:
# [['Children - Radio Edit',
#   'Croce',
#   'Devotion - Show Me Love 2023 Techno Mix - Radio Edit',
#   "You're Toxic",
#   'Gam Gam - 2023'],
#  ['Oh Qué Será?',
#   'Talento De Televisión',
#   'Idilio',
#   'El Día De Mi Suerte',
#   'Pedro Navaja'],
#  ["Comptine d'un autre été, l'après-midi",
#   "La Valse d'Amélie - Version piano",
#   'Le Matin',
#   "I've Never Been There",
#   "La valse d'Amélie"]]

# %%
artists
# Out:
# ['Deborah de Luca', 'Willie Colón', 'Yann Tiersen']

# %%
diccionario = dict(zip(artists, top_tracks_list))
diccionario
# Out:
# {'Deborah de Luca': ['Children - Radio Edit',
#   'Croce',
#   'Devotion - Show Me Love 2023 Techno Mix - Radio Edit',
#   "You're Toxic",
#   'Gam Gam - 2023'],
#  'Willie Colón': ['Oh Qué Será?',
#   'Talento De Televisión',
#   'Idilio',
#   'El Día De Mi Suerte',
#   'Pedro Navaja'],
#  'Yann Tiersen': ["Comptine d'un autre été, l'après-midi",
#   "La Valse d'Amélie - Version piano",
#   'Le Matin',
#   "I've Never Been There",
#   "La valse d'Amélie"]}

# %% [markdown]
# Discover Related Artists:
#
# Write a function named find_related_artists.
# This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#
# Store the results in a list named related_artists_list.

# %%
resultado_artist = sp.search( q = "Willie Colón" , limit = 1, type = "artist")

resultado_artist["artists"]['items'][0]["id"]
# Out:
# '7x5Slu7yTE5icZjNsc3OzW'

# %%
def find_related_artists(name):
    
    related_artists_list = []
    
    results_ = sp.search( q = name , limit = 1, type='artist')
    uri = results_["artists"]['items'][0]["id"]
    related = sp.artist_related_artists(uri)
    
    for i in range(5):
        artist = related['artists'][i]["name"]
        related_artists_list.append(artist)
    
    return (related_artists_list)

# %%
related_Willie = find_related_artists("Willie Colón")

# %%
related_Willie
# Out:
# ['Rubén Blades',
#  'Héctor Lavoe',
#  'Cheo Feliciano',
#  'Andy Montañez',
#  'Fania All Stars']

# %%
related['artists'][0]["name"]
# Out:
# 'Rubén Blades'

# %%
related['artists'][10]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5S3BxZrK4hYN3fwsw8oumq'},
#  'followers': {'href': None, 'total': 558410},
#  'genres': ['salsa', 'salsa puertorriquena'],
#  'href': 'https://api.spotify.com/v1/artists/5S3BxZrK4hYN3fwsw8oumq',
#  'id': '5S3BxZrK4hYN3fwsw8oumq',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb93a3adae34178f1cee4da912',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517493a3adae34178f1cee4da912',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17893a3adae34178f1cee4da912',
#    'width': 160}],
#  'name': 'Ismael Miranda',
#  'popularity': 47,
#  'type': 'artist',
#  'uri': 'spotify:artist:5S3BxZrK4hYN3fwsw8oumq'}

# %% [markdown]
# Challenge: Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# Iterating for Multiple Artists:
# Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.

# %%
name = "Willie Colón"
top_5_related = find_related_artists(name)
top_5_related
# Out:
# ['Rubén Blades',
#  'Héctor Lavoe',
#  'Cheo Feliciano',
#  'Andy Montañez',
#  'Fania All Stars']

# %%
play_list_related = [get_top_tracks(artist) for artist in top_5_related]

# %%
play_list_related[0]
# Out:
# ['Decisiones',
#  'Amor y Control',
#  'Pedro Navaja',
#  'Oh Qué Será?',
#  'Te Están Buscando']

# %%
play_list_related
# Out:
# [['Decisiones',
#   'Amor y Control',
#   'Pedro Navaja',
#   'Oh Qué Será?',
#   'Te Están Buscando'],
#  ['El Cantante',
#   'Periódico De Ayer',
#   'El Día De Mi Suerte',
#   'Juanito Alimaña',
#   'Todo Tiene Su Final'],
#  ['Anacaona',
#   'El Ratón',
#   'De Ti Depende',
#   "El Pito (I'll Never Go Back To Georgia)",
#   'Yo No Soy Un Ángel'],
#  ['Casi Te Envidio',
#   'Milonga para una Niña',
#   'Casi Te Envidio',
#   'Payaso',
#   'Me Gusta'],
#  ['Medley: Puerto Rico / Adoración - Live',
#   'El Rey de la Puntualidad',
#   'Quítate Tú - Live',
#   'Allegria',
#   'Quítate Tú - Live']]

# %%
play_list = [] 
for i in play_list_related:
    for j in i:
        play_list.append(j)

# %%
play_list
# Out:
# ['Decisiones',
#  'Amor y Control',
#  'Pedro Navaja',
#  'Oh Qué Será?',
#  'Te Están Buscando',
#  'El Cantante',
#  'Periódico De Ayer',
#  'El Día De Mi Suerte',
#  'Juanito Alimaña',
#  'Todo Tiene Su Final',
#  'Anacaona',
#  'El Ratón',
#  'De Ti Depende',
#  "El Pito (I'll Never Go Back To Georgia)",
#  'Yo No Soy Un Ángel',
#  'Casi Te Envidio',
#  'Milonga para una Niña',
#  'Casi Te Envidio',
#  'Payaso',
#  'Me Gusta',
#  'Medley: Puerto Rico / Adoración - Live',
#  'El Rey de la Puntualidad',
#  'Quítate Tú - Live',
#  'Allegria',
#  'Quítate Tú - Live']

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
# Your answer here

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Die wichtigsten Deutschrap Releases der letzten Wochen - jeden Freitag aktualisiert. Cover: Lucio101, KALIM',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWSTqUqJcxFk6'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWSTqUqJcxFk6',
#     'id': '37i9dQZF1DWSTqUqJcxFk6',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000261a6c39b85f0e12bd10a45c6',
#       'width': None}],
#     'name': 'Deutschrap Brandneu',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#ffffff',
# ...

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# You Are My Sunshine
# La Vie En Rose
# Sunday Morning - Acoustic
# Too Good At Goodbyes - Acoustic
# I'm Not the Only One - Live from Spotify, London
# True Colours
# Cold Heart - Acoustic
# September Song - Guitar Acoustic
# Collide - Acoustic Version
# Baby One More Time - Recorded at Spotify Studios New York City
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# When You Love Someone - Acoustic
# Rockabye - Acoustic Version
# Blinding Lights
# Little Talks
# Ain't Nobody (Loves Me Better) - Acoustic
# Shape of You - Acoustic
# What About Us - Acoustic
# Linger
# Something Just Like This - Acoustic
# Let It Go - James Bay Spotify Session 2015
# 1973 - Acoustic
# Billie Jean
# Heaven Is a Place on Earth
# Perfect - Acoustic
# Naked - Acoustic Version
# Crazy in Love
# Firestone - Live Acoustic Version
# Wild Love - Acoustic
# Fix You - Live
# Can't Help Falling in Love
# Price Tag - Acoustic Version
# Chasing Cars
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Aitch', 'Luciano', 'GReeeN', '$OHO BANI', 'Herbert Grönemeyer', 'Ericson', 'AYLIVA', 'Baby B3ns', 'Yung Hurn', 'CIVO', 'Eminem', 'FOURTY', 'Bausa', 'Tream', 'treamiboii', 'Lithe', 'Apache 207', '6PM RECORDS', 'Ski Aggu', 'Haaland936', 'SIRA', 'Leony', 'Jaxomy', 'Agatino Romero', 'Raffaella Carrà', 'Olexesh', 'Ataypapi', 'ilo 7araga', 'LEA', 'Dhurata Dora', 'Pashanim', 'Zartmann', 'Dauner', 'Chappell Roan', 'Lune', 'Kauta', 'Adam Port', 'Stryv', 'Keinemusik', 'Orso', 'Malachiii', 'BENNETT', 'KATI K', 'FiNCH', 'SDP', 'Sido', 'Esther Graf', '01099', 'Gustav', 'Paul', 'Zachi', 'Myles Smith', 'Montez', 'The Kid LAROI', 'MilleniumKid', 'JBS', 'TIM PLVNK', 'Dimitri Vegas & Like Mike', 'Tiësto', 'Dido', 'W&W', 'Dimitri Vegas', 'Like Mike', 'David Guetta', 'OneRepublic', 'Shaboozey', 'Nina Chuba', 'FloyyMenor', 'Cris Mj', 'Artemas', 'Billie Eilish', 'Mark Ambor', 'MEDUZA', 'Tommy Richman', 'Isabel LaRosa', 'Sabrina Carpenter', 'Zerb', 'Sofiya Nzau', 'Hozier', 'Central Cee', 'Lil Baby', 'Das
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %% [markdown]
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.

# %%
featured = sp.featured_playlists()

# %%
featured['playlists']['items'][0]['id']
# Out:
# '37i9dQZF1DWSTqUqJcxFk6'

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description

# %%
top_5_featured_id = []
top_5_featured_names = []

for i in range(5):
    
    id_playlist = featured['playlists']['items'][i]['id']
    top_5_featured_id.append(id_playlist)  
    
    name_playlist = featured['playlists']['items'][i]['name']
    top_5_featured_names.append(name_playlist)

# %%
top_5_featured_id
# Out:
# ['37i9dQZF1DWSTqUqJcxFk6',
#  '37i9dQZF1DWUW2bvSkjcJ6',
#  '37i9dQZF1DX4jP4eebSWR9',
#  '37i9dQZF1DX36edUJpD76c',
#  '37i9dQZF1DX05r4Oy3Ln97']

# %%
top_5_featured_names
# Out:
# ['Deutschrap Brandneu',
#  'New Music Friday Deutschland',
#  'Hot Hits Deutschland',
#  'Modus Mio',
#  'Summer House 2024']

# %% [markdown]
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.

# %%
play_id = "37i9dQZF1DX4jP4eebSWR9"

# %%
play_list = sp.playlist(play_id)
play_list
# Out:
# {'collaborative': False,
#  'description': '50 Hits in einer Playlist! Cover: Aitch, Luciano',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4jP4eebSWR9'},
#  'followers': {'href': None, 'total': 2597839},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4jP4eebSWR9?additional_types=track',
#  'id': '37i9dQZF1DX4jP4eebSWR9',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f000000029fba8f8e48271576f5eb1d49',
#    'width': None}],
#  'name': 'Hot Hits Deutschland',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#C3F0C8',
#  'public': True,
#  'snapshot_id': 'ZnrgTQAAAABSb4vM4Xrjf8rnG0hI8dS6',
# ...

# %%
print(play_list['name'])  # Print the playlist's name
print(play_list['description'])  # Print the playlist's description
# Out:
# Hot Hits Deutschland
# 50 Hits in einer Playlist! Cover: Aitch, Luciano

# %% [markdown]
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.

# %%
tracks = sp.playlist_tracks(play_id)

for track in tracks['items'][:10]:
    print(track['track']['name'])
# Out:
# Baddies
# Panama
# ZEIT, DASS SICH WAS DREHT
# Beifahrer
# Liebe in Stereo
# Mach die Augen auf
# Houdini
# VEMPA
# Dieser Sommer
# Fall Back

# %%
tracks = sp.playlist_tracks(play_id)
tracks_10 = []

for track in tracks['items'][:10]:
    track = track['track']['name']
    tracks_10.append(track)

# %%
tracks_10
# Out:
# ['Baddies',
#  'Panama',
#  'ZEIT, DASS SICH WAS DREHT',
#  'Beifahrer',
#  'Liebe in Stereo',
#  'Mach die Augen auf',
#  'Houdini',
#  'VEMPA',
#  'Dieser Sommer',
#  'Fall Back']

# %% [markdown]
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
# Your answer here

artists_list = []

for track_item in tracks['items'][:10]:
    track = track_item['track']
    track_temporal = []  # Lista temporal para los artistas de la pista actual ...esto NO LO ENTENDÍ BIEN!!!
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in track_temporal:  # This ensures each artist is added only once
            track_temporal.append(artist_name)
    artists_list.append(track_temporal)

print(artists_list)
# Out:
# [['Aitch', 'Luciano'], ['GReeeN'], ['$OHO BANI', 'Herbert Grönemeyer', 'Ericson'], ['AYLIVA'], ['Baby B3ns', 'Yung Hurn'], ['CIVO'], ['Eminem'], ['FOURTY', 'Bausa'], ['Tream', 'treamiboii'], ['Lithe']]

# %%
len(tracks['items']) #len(tracks['items'][:10])
# Out:
# 50

# %%
tracks['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KQylwDxYE7Vxli0BSuwaf'},
#   'href': 'https://api.spotify.com/v1/artists/3KQylwDxYE7Vxli0BSuwaf',
#   'id': '3KQylwDxYE7Vxli0BSuwaf',
#   'name': '$OHO BANI',
#   'type': 'artist',
#   'uri': 'spotify:artist:3KQylwDxYE7Vxli0BSuwaf'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5tG5dl5mS2wB5w72YBpsyg'},
#   'href': 'https://api.spotify.com/v1/artists/5tG5dl5mS2wB5w72YBpsyg',
#   'id': '5tG5dl5mS2wB5w72YBpsyg',
#   'name': 'Herbert Grönemeyer',
#   'type': 'artist',
#   'uri': 'spotify:artist:5tG5dl5mS2wB5w72YBpsyg'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2mkCm5VNJTplOKJxcDYMpa'},
#   'href': 'https://api.spotify.com/v1/artists/2mkCm5VNJTplOKJxcDYMpa',
#   'id': '2mkCm5VNJTplOKJxcDYMpa',
#   'name': 'Ericson',
#   'type': 'artist',
#   'uri': 'spotify:artist:2mkCm5VNJTplOKJxcDYMpa'}]

# %%
tracks['items'][2]['track']['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3KQylwDxYE7Vxli0BSuwaf'},
#  'href': 'https://api.spotify.com/v1/artists/3KQylwDxYE7Vxli0BSuwaf',
#  'id': '3KQylwDxYE7Vxli0BSuwaf',
#  'name': '$OHO BANI',
#  'type': 'artist',
#  'uri': 'spotify:artist:3KQylwDxYE7Vxli0BSuwaf'}

# %%
tracks['items'][2]['track']['artists'][1]['name']
# Out:
# 'Herbert Grönemeyer'

# %%
track['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LVC96BEVGugTAp38AajV6'},
#   'href': 'https://api.spotify.com/v1/artists/7LVC96BEVGugTAp38AajV6',
#   'id': '7LVC96BEVGugTAp38AajV6',
#   'name': 'Lithe',
#   'type': 'artist',
#   'uri': 'spotify:artist:7LVC96BEVGugTAp38AajV6'}]

# %%
dict_tracks_artists = dict(zip(tracks_10,artists_list))

# %%
dict_tracks_artists
# Out:
# {'Baddies': ['Aitch', 'Luciano'],
#  'Panama': ['GReeeN'],
#  'ZEIT, DASS SICH WAS DREHT': ['$OHO BANI', 'Herbert Grönemeyer', 'Ericson'],
#  'Beifahrer': ['AYLIVA'],
#  'Liebe in Stereo': ['Baby B3ns', 'Yung Hurn'],
#  'Mach die Augen auf': ['CIVO'],
#  'Houdini': ['Eminem'],
#  'VEMPA': ['FOURTY', 'Bausa'],
#  'Dieser Sommer': ['Tream', 'treamiboii'],
#  'Fall Back': ['Lithe']}
